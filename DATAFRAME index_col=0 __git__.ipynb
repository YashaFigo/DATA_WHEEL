# %% [markdown]
# ### When loading the below dataframe from csv, it creates a redundant index column called Unnamed: 0.
#
# Heres how to get rid of it:

# %%
data = pd.read_csv('data_for_prep.csv')
data[:20]
# Out:
#     Unnamed: 0  preg  plas  pres  skin  test  mass   pedi  age  class
# 0            0     6   148    72    35     0  33.6  0.627   50      1
# 1            1     1    85    66    29     0  26.6  0.351   31      0
# 2            2     8   183    64     0     0  23.3  0.672   32      1
# 3            3     1    89    66    23    94  28.1  0.167   21      0
# 4            4     0   137    40    35   168  43.1  2.288   33      1
# 5            5     5   116    74     0     0  25.6  0.201   30      0
# 6            6     3    78    50    32    88  31.0  0.248   26      1
# 7            7    10   115     0     0     0  35.3  0.134   29      0
# 8            8     2   197    70    45   543  30.5  0.158   53      1
# 9            9     8   125    96     0     0   0.0  0.232   54      1
# 10          10     4   110    92     0     0  37.6  0.191   30      0
# 11          11    10   168    74     0     0  38.0  0.537   34      1
# ...

# %% [markdown]
# <b>>>>SCROLL DOWN FOR ANSWER<<<

# %% [markdown]
# ---

# %%
data = pd.read_csv('data_for_prep.csv',index_col=0)
data[:10]
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1
# 5     5   116    74     0     0  25.6  0.201   30      0
# 6     3    78    50    32    88  31.0  0.248   26      1
# 7    10   115     0     0     0  35.3  0.134   29      0
# 8     2   197    70    45   543  30.5  0.158   53      1
# 9     8   125    96     0     0   0.0  0.232   54      1

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
import pandas as pd
